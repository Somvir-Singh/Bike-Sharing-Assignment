# %% [markdown]
# <a href="https://colab.research.google.com/github/Somvir-Singh/Bike-Sharing-Assignment/blob/main/Copy_of_Final_image_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install opencv-python matplotlib

# %%
import cv2
import matplotlib.pyplot as plt

# %%
import cv2
import matplotlib.pyplot as plt
import zipfile
import os

# Function to perform image analysis
def analyze_frames(zip_path, avi_filenames):
    differences_all = []
    vertical_coordinates_all = []

    for avi_filename in avi_filenames:
        # Extract the contents of the zip folder
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall('CNN_image_analysis')

        # Path to the extracted AVI file
        avi_path = os.path.join('CNN_image_analysis', avi_filename)
        print(avi_path)
        # Read video
        cap = cv2.VideoCapture(avi_path)

        differences = []
        vertical_coordinates = []
        print(cap.isOpened())
        while cap.isOpened():
            ret, frame = cap.read()

            if not ret:
                break

            # Perform image processing, object detection, and tracking
            # Extract bead positions (assuming a list of bead positions)
            # Example: Assuming bead_positions is a list of (x, y) coordinates
            bead_positions = []  # Replace this with the actual code to get bead positions

            first_bead_y = bead_positions[0][1]  # vertical coordinate of the first bead
            last_bead_y = bead_positions[-1][1]  # vertical coordinate of the last bead
            print(first_bead_y)
            print(last_bead_y)

            difference = last_bead_y - first_bead_y
            differences.append(difference)

            # You need to replace this with the actual code to extract the vertical coordinate
            vertical_coordinate = 0
            vertical_coordinates.append(vertical_coordinate)

        cap.release()

        differences_all.append(differences)
        vertical_coordinates_all.append(vertical_coordinates)

    return differences_all, vertical_coordinates_all

# Example usage
zip_path = '/content/CNN_image_analysis.zip'
avi_filenames = ['video5a.AVI', 'video5b.AVI', 'video5c.AVI', 'video6a.AVI', 'video6b.AVI', 'video6c.AVI', 'video7a.AVI', 'video7c.AVI', 'video8a.AVI', 'video8c.AVI']
differences_all, vertical_coordinates_all = analyze_frames(zip_path, avi_filenames)

# Plotting
for i in range(len(avi_filenames)):
    plt.plot(differences_all[i], vertical_coordinates_all[i], label=f'Video {i+1}')


plt.xlabel('Difference in Vertical Coordinates')
plt.ylabel('Vertical Coordinate')
plt.title('Difference between the Vertical Coordinates of First and Last Beads')
plt.legend()
plt.show()
# Out:
# CNN_image_analysis/video5a.AVI
# False
# CNN_image_analysis/video5b.AVI
# False
# CNN_image_analysis/video5c.AVI
# False
# CNN_image_analysis/video6a.AVI
# False
# CNN_image_analysis/video6b.AVI
# False
# CNN_image_analysis/video6c.AVI
# False
# CNN_image_analysis/video7a.AVI
# False
# CNN_image_analysis/video7c.AVI
# False
# CNN_image_analysis/video8a.AVI
# False
# CNN_image_analysis/video8c.AVI
# False

# %%
import cv2
import matplotlib.pyplot as plt
import zipfile
import os
import numpy as np

# Function to perform image analysis
def analyze_frames(zip_path, avi_filenames):
    all_results = []

    for avi_filename in avi_filenames:
        # Extract the contents of the zip folder
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall('CNN_image_analysis')

        # Path to the extracted AVI file
        avi_path = os.path.join('CNN_image_analysis', avi_filename)

        # Read video
        cap = cv2.VideoCapture(avi_path)

        differences = []
        vertical_coordinates = []
        timestamps = []

        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        fps = cap.get(cv2.CAP_PROP_FPS)

        for frame_number in range(frame_count):
            ret, frame = cap.read()

            if not ret:
                break

            # Perform image processing, object detection, and tracking
            # Extract bead positions (assuming a list of bead positions)
            # Example: Assuming bead_positions is a list of (x, y) coordinates
            bead_positions = []  # Replace this with the actual code to get bead positions

            first_bead_y = bead_positions[0][1]  # vertical coordinate of the first bead
            last_bead_y = bead_positions[-1][1]  # vertical coordinate of the last bead

            difference = last_bead_y - first_bead_y
            differences.append(difference)

            # You need to replace this with the actual code to extract the vertical coordinate
            vertical_coordinate = 0
            vertical_coordinates.append(vertical_coordinate)

            # Calculate timestamp based on frame number and FPS
            timestamp = frame_number / fps
            timestamps.append(timestamp)

        cap.release()

        results = {
            'avi_filename': avi_filename,
            'differences': differences,
            'vertical_coordinates': vertical_coordinates,
            'timestamps': timestamps
        }

        all_results.append(results)

    return all_results

# Example usage
zip_path = '/content/CNN_image_analysis.zip'
avi_filenames = ['video5a.AVI', 'video5b.AVI', 'video5c.AVI', 'video6a.AVI', 'video6b.AVI', 'video6c.AVI', 'video7a.AVI', 'video7c.AVI', 'video8a.AVI', 'video8c.AVI']
all_results = analyze_frames(zip_path, avi_filenames)

# Statistical Analysis and Visualization
for result in all_results:
    differences = np.array(result['differences'])
    vertical_coordinates = np.array(result['vertical_coordinates'])

    mean_difference = np.mean(differences)
    std_difference = np.std(differences)

    # Additional statistical analyses can be performed

    # Visualization
    plt.figure(figsize=(10, 6))

    # Plotting differences against timestamps
    plt.subplot(2, 1, 1)
    plt.plot(result['timestamps'], differences, label='Differences')
    plt.xlabel('Time (seconds)')
    plt.ylabel('Difference in Vertical Coordinates')
    plt.title(f'Differences over Time - {result["avi_filename"]}')
    plt.legend()

    # Plotting vertical coordinates against timestamps
    plt.subplot(2, 1, 2)
    plt.plot(result['timestamps'], vertical_coordinates, label='Vertical Coordinates')
    plt.xlabel('Time (seconds)')
    plt.ylabel('Vertical Coordinate')
    plt.title(f'Vertical Coordinates over Time - {result["avi_filename"]}')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
import cv2
import matplotlib.pyplot as plt
import zipfile
import os
import numpy as np

# Function to perform image analysis
def analyze_frames(zip_path, avi_filenames):
    all_results = []

    for avi_filename in avi_filenames:
        # Extract the contents of the zip folder
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall('CNN_image_analysis')

        # Path to the extracted AVI file
        avi_path = os.path.join('CNN_image_analysis', avi_filename)

        # Read video
        cap = cv2.VideoCapture(avi_path)

        differences = []
        vertical_coordinates = []
        timestamps = []

        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        fps = cap.get(cv2.CAP_PROP_FPS)


        for frame_number in range(frame_count):
            ret, frame = cap.read()

            if not ret:
                break

            # Perform image processing, object detection, and tracking
            # Extract bead positions (assuming a list of bead positions)
            # Example: Assuming bead_positions is a list of (x, y) coordinates
            bead_positions = [(x1, y1), (x2, y2), ..., (xn, yn)]  # Replace this with the actual code to get bead positions

            first_bead_y = bead_positions[0][1]  # vertical coordinate of the first bead
            last_bead_y = bead_positions[-1][1]  # vertical coordinate of the last bead

            difference = last_bead_y - first_bead_y
            differences.append(difference)

            # You need to replace this with the actual code to extract the vertical coordinate
            vertical_coordinates = [y for _, y in bead_positions]
            vertical_coordinates.append(vertical_coordinates)

            # Calculate timestamp based on frame number and FPS
            timestamp = frame_number / fps
            timestamps.append(timestamp)

        cap.release()

        results = {
            'avi_filename': avi_filename,
            'differences': differences,
            'vertical_coordinates': vertical_coordinates,
            'timestamps': timestamps
        }

        all_results.append(results)

    return all_results

# Example usage
zip_path = '/content/CNN_image_analysis.zip'
avi_filenames = ['video5a.AVI', 'video5b.AVI', 'video5c.AVI', 'video6a.AVI', 'video6b.AVI', 'video6c.AVI', 'video7a.AVI', 'video7c.AVI', 'video8a.AVI', 'video8c.AVI']
all_results = analyze_frames(zip_path, avi_filenames)

# Statistical Analysis and Visualization
for result in all_results:
    differences = np.array(result['differences'])
    vertical_coordinates = np.array(result['vertical_coordinates'])

    mean_difference = np.mean(differences)
    std_difference = np.std(differences)

    # Additional statistical analyses can be performed

    # Visualization
    plt.figure(figsize=(10, 6))

    # Plotting differences against timestamps
    plt.subplot(2, 1, 1)
    plt.plot(result['timestamps'], differences, label='Differences')
    plt.xlabel('Time (seconds)')
    plt.ylabel('Difference in Vertical Coordinates')
    plt.title(f'Differences over Time - {result["avi_filename"]}')
    plt.legend()

    plt.tight_layout()
    plt.show()

    # Plotting vertical coordinates against timestamps
    plt.figure(figsize=(10, 6))
    plt.subplot(2, 1, 2)
    plt.plot(result['timestamps'], vertical_coordinates, label='Vertical Coordinates')
    plt.xlabel('Time (seconds)')
    plt.ylabel('Vertical Coordinate')
    plt.title(f'Vertical Coordinates over Time - {result["avi_filename"]}')
    plt.legend()

    plt.tight_layout()
    plt.show()
